# %% [markdown]
# <a href="https://colab.research.google.com/github/bala-codes/Yolo-v5_Object-Detection_Blood_Cell_Count/blob/master/codes/BCC%20INFERENCE%20Yolo-v5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys, random
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install -qr '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/requirements.txt'  # install dependencies

# %% [markdown]
# #**NECCESSARY FILES FOR DETECTION AND LATER ADD THIS PATH TO THE SYSTEM VARIABLE**

# %% [markdown]
# ![alt text](https://github.com/bala-codes/Yolo-v5_Object-Detection_Blood_Cell_Count/blob/master/imgs/Dependency_files.PNG?raw=true)

# %%
## Add the path where you have stored the neccessary supporting files to run detect.py ##
sys.path.insert(0, '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/')
print(sys.path)
cwd = os.getcwd()
print(cwd)
# Out:
# ['/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/', '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE_CODES/', '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE_CODES/', '', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython']
# /content

# %% [markdown]
# ## Single Image predictions

# %%
## Beware the contents in the output folder will be deleted for every prediction
output = !python '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/detect.py' --source '/content/BloodImage_00026.jpg' --weights '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/best_BCCM.pt' --output '/content/OUTPUTS/' --device 'cpu'

print(output)
# Out:
# ["Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='cpu', img_size=640, iou_thres=0.5, output='/content/OUTPUTS/', save_txt=False, source='/content/BloodImage_00026.jpg', update=False, view_img=False, weights=['/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/best_BCCM.pt'])", 'Using CPU', '', 'Fusing layers... Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients', 'image 1/1 /content/BloodImage_00026.jpg: 512x640 19 RBCs, 1 WBCs, Done. (0.469s)', 'Results saved to /content/OUTPUTS', 'Done. (0.653s)']

# %%
output
# Out:
# ["Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='cpu', img_size=640, iou_thres=0.5, output='/content/OUTPUTS/', save_txt=False, source='/content/BloodImage_00026.jpg', update=False, view_img=False, weights=['/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/best_BCCM.pt'])",
#  'Using CPU',
#  '',
#  'Fusing layers... Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients',
#  'image 1/1 /content/BloodImage_00026.jpg: 512x640 19 RBCs, 1 WBCs, Done. (0.469s)',
#  'Results saved to /content/OUTPUTS',
#  'Done. (0.653s)']

# %%
img = plt.imread('/content/OUTPUTS/BloodImage_00026.jpg')
plt.imshow(img)

# %% [markdown]
# ## Predict image in folders

# %%
output = !python '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/detect.py' --source '/content/inputs/' --weights '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/best_BCCM.pt' --output '/content/OUTPUTS/' --device 'cpu'

print(output)
# Out:
# ["Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='cpu', img_size=640, iou_thres=0.5, output='/content/OUTPUTS/', save_txt=False, source='/content/inputs/', update=False, view_img=False, weights=['/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/best_BCCM.pt'])", 'Using CPU', '', 'Fusing layers... Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients', 'image 1/2 /content/inputs/BloodImage_00000.jpg: 512x640 16 RBCs, 1 WBCs, Done. (0.416s)', 'image 2/2 /content/inputs/BloodImage_00026.jpg: 512x640 19 RBCs, 1 WBCs, Done. (0.387s)', 'Results saved to /content/OUTPUTS', 'Done. (1.003s)']

# %%
output
# Out:
# ["Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='cpu', img_size=640, iou_thres=0.5, output='/content/OUTPUTS/', save_txt=False, source='/content/inputs/', update=False, view_img=False, weights=['/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/best_BCCM.pt'])",
#  'Using CPU',
#  '',
#  'Fusing layers... Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients',
#  'image 1/2 /content/inputs/BloodImage_00000.jpg: 512x640 16 RBCs, 1 WBCs, Done. (0.416s)',
#  'image 2/2 /content/inputs/BloodImage_00026.jpg: 512x640 19 RBCs, 1 WBCs, Done. (0.387s)',
#  'Results saved to /content/OUTPUTS',
#  'Done. (1.003s)']

# %%
disp_images = glob('/content/OUTPUTS/*')

img = plt.imread(disp_images[0])
plt.imshow(img)

# %%
img = plt.imread(disp_images[1])
plt.imshow(img)
